# %%
import torch as th
import torch.nn as nn
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor


class CustomCNN(BaseFeaturesExtractor):
    """
    :param observation_space: (gym.Space)
    :param features_dim: (int) Number of features extracted.
        This corresponds to the number of unit for the last layer.
    """

    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 256):
        super(CustomCNN, self).__init__(observation_space, features_dim)
        # We assume CxHxW images (channels first)
        # Re-ordering will be done by pre-preprocessing or wrapper
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.AvgPool2d(2),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with th.no_grad():
            n_flatten = self.cnn(
                th.as_tensor(observation_space.sample()[None]).float()
            ).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: th.Tensor) -> th.Tensor:
        print(self.cnn(observations).shape)
        return self.linear(self.cnn(observations))

policy_kwargs = dict(
    features_extractor_class=CustomCNN,
    features_extractor_kwargs=dict(features_dim=128),
    net_arch=[16, 1024, 32, 32, 16, 4]
)
# model = PPO("CnnPolicy", "BreakoutNoFrameskip-v4", policy_kwargs=policy_kwargs, verbose=1)
# model.learn(1000)

# %%
from M2048Cnn import M2048
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
import numpy as np

def linear_schedule(initial_value, final_value=0.0):

    if isinstance(initial_value, str):
        initial_value = float(initial_value)
        final_value = float(final_value)
        assert (initial_value > 0.0)

    def scheduler(progress):
        return final_value + progress * (initial_value - final_value)

    return scheduler

NUM_ENVS = 32
make_env = lambda seed=None: Monitor(M2048(4, seed=seed))
# env = SubprocVecEnv([make_env(seed=s) for s in np.random.randint(1,1e9, NUM_ENVS)])
env = DummyVecEnv([make_env])
# env = ActionMasker(env, MinesweeperEnv.get_action_mask)
lr_schedule = linear_schedule(2.5e-2, 2.5e-5)
clip_range_schedule = linear_schedule(0.15, 0.025)
if 0:
    model = MaskablePPO(
        "MlpPolicy", 
        env=env, 
        batch_size=2048 * 16,
        policy_kwargs=policy_kwargs,
        verbose=1,
        tensorboard_log="./tensorboard/",
        learning_rate=lr_schedule,
        clip_range=clip_range_schedule,
        device='cuda',
    )
else:
    model = MaskablePPO.load("./model/2048_14.pkl", env=env)
for i in range(100):
    model.learn(total_timesteps=1e5)
    model.save(f"./model/2048_{i}.pkl")
# Out:
# Logging to ./tensorboard/PPO_24
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 169      |
# |    ep_rew_mean     | 1.64e+03 |
# | time/              |          |
# |    fps             | 778      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 1.52e+03     |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0021813652 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.147        |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0245       |
# |    loss                 | 1.26e+04     |
# |    n_updates            | 8830         |
# |    policy_gradient_loss | -0.000638    |
# |    value_loss           | 2.51e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 1.53e+03     |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0069133146 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.145        |
# |    entropy_loss         | -0.794       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.024        |
# |    loss                 | 1.15e+04     |
# |    n_updates            | 8840         |
# |    policy_gradient_loss | -0.000227    |
# |    value_loss           | 2.31e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | 1.52e+03     |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 4            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0036034328 |
# |    clip_fraction        | 0.0722       |
# |    clip_range           | 0.142        |
# |    entropy_loss         | -0.765       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0235       |
# |    loss                 | 1.23e+04     |
# |    n_updates            | 8850         |
# |    policy_gradient_loss | -0.000496    |
# |    value_loss           | 2.46e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 162           |
# |    ep_rew_mean          | 1.48e+03      |
# | time/                   |               |
# |    fps                  | 355           |
# |    iterations           | 5             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00071465253 |
# |    clip_fraction        | 0.0281        |
# |    clip_range           | 0.14          |
# |    entropy_loss         | -0.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.023         |
# |    loss                 | 1.24e+04      |
# |    n_updates            | 8860          |
# |    policy_gradient_loss | -2.54e-05     |
# |    value_loss           | 2.48e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 1.46e+03     |
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 6            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0021614288 |
# |    clip_fraction        | 0.152        |
# |    clip_range           | 0.137        |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0224       |
# |    loss                 | 1.12e+04     |
# |    n_updates            | 8870         |
# |    policy_gradient_loss | 0.00665      |
# |    value_loss           | 2.25e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 1.44e+03    |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 7           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020630782 |
# |    clip_fraction        | 0.571       |
# |    clip_range           | 0.135       |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0219      |
# |    loss                 | 1.11e+04    |
# |    n_updates            | 8880        |
# |    policy_gradient_loss | 0.0213      |
# |    value_loss           | 2.22e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 1.44e+03    |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 8           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014251343 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.132       |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0214      |
# |    loss                 | 1.32e+04    |
# |    n_updates            | 8890        |
# |    policy_gradient_loss | 0.00975     |
# |    value_loss           | 2.63e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 158          |
# |    ep_rew_mean          | 1.43e+03     |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 9            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0017303319 |
# |    clip_fraction        | 0.0942       |
# |    clip_range           | 0.13         |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0209       |
# |    loss                 | 1.15e+04     |
# |    n_updates            | 8900         |
# |    policy_gradient_loss | 0.000453     |
# |    value_loss           | 2.3e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | 1.38e+03     |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 10           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0012412212 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.127        |
# |    entropy_loss         | -0.735       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0204       |
# |    loss                 | 9.97e+03     |
# |    n_updates            | 8910         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 2e+04        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 1.35e+03    |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 11          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.001272341 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.124       |
# |    entropy_loss         | -0.756      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0199      |
# |    loss                 | 1.22e+04    |
# |    n_updates            | 8920        |
# |    policy_gradient_loss | -0.000852   |
# |    value_loss           | 2.44e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 1.37e+03     |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 12           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0012616625 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.122        |
# |    entropy_loss         | -0.762       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0194       |
# |    loss                 | 1.19e+04     |
# |    n_updates            | 8930         |
# |    policy_gradient_loss | 8.87e-05     |
# |    value_loss           | 2.39e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 157           |
# |    ep_rew_mean          | 1.43e+03      |
# | time/                   |               |
# |    fps                  | 330           |
# |    iterations           | 13            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00039485295 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.119         |
# |    entropy_loss         | -0.73         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0189        |
# |    loss                 | 1.2e+04       |
# |    n_updates            | 8940          |
# |    policy_gradient_loss | -5.11e-05     |
# |    value_loss           | 2.4e+04       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 1.41e+03    |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 14          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.001632509 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.117       |
# |    entropy_loss         | -0.766      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0184      |
# |    loss                 | 1.17e+04    |
# |    n_updates            | 8950        |
# |    policy_gradient_loss | -0.000283   |
# |    value_loss           | 2.33e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | 1.4e+03      |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 15           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0011561253 |
# |    clip_fraction        | 0.0773       |
# |    clip_range           | 0.114        |
# |    entropy_loss         | -0.802       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0178       |
# |    loss                 | 1.09e+04     |
# |    n_updates            | 8960         |
# |    policy_gradient_loss | 0.000471     |
# |    value_loss           | 2.18e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 1.31e+03     |
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 16           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0006936643 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.112        |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0173       |
# |    loss                 | 1.21e+04     |
# |    n_updates            | 8970         |
# |    policy_gradient_loss | 0.000526     |
# |    value_loss           | 2.41e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | 1.29e+03     |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 17           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0020913528 |
# |    clip_fraction        | 0.0857       |
# |    clip_range           | 0.109        |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0168       |
# |    loss                 | 1.25e+04     |
# |    n_updates            | 8980         |
# |    policy_gradient_loss | 0.00119      |
# |    value_loss           | 2.51e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | 1.28e+03     |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 18           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0003045522 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.106        |
# |    entropy_loss         | -0.773       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0163       |
# |    loss                 | 1.13e+04     |
# |    n_updates            | 8990         |
# |    policy_gradient_loss | -1.36e-05    |
# |    value_loss           | 2.27e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | 1.2e+03      |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 19           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0011903977 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.104        |
# |    entropy_loss         | -0.793       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0158       |
# |    loss                 | 1.18e+04     |
# |    n_updates            | 9000         |
# |    policy_gradient_loss | -0.000233    |
# |    value_loss           | 2.35e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 1.15e+03     |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 20           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0005201186 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.101        |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0153       |
# |    loss                 | 1.31e+04     |
# |    n_updates            | 9010         |
# |    policy_gradient_loss | 6.3e-05      |
# |    value_loss           | 2.61e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 1.19e+03     |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 21           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0012819208 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.0988       |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0148       |
# |    loss                 | 1.18e+04     |
# |    n_updates            | 9020         |
# |    policy_gradient_loss | -0.000597    |
# |    value_loss           | 2.36e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 1.19e+03     |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 22           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0010880633 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.0962       |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0143       |
# |    loss                 | 1.48e+04     |
# |    n_updates            | 9030         |
# |    policy_gradient_loss | 0.000757     |
# |    value_loss           | 2.95e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 143          |
# |    ep_rew_mean          | 1.24e+03     |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 23           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0012700199 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.0937       |
# |    entropy_loss         | -0.847       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0137       |
# |    loss                 | 1.23e+04     |
# |    n_updates            | 9040         |
# |    policy_gradient_loss | -0.000674    |
# |    value_loss           | 2.45e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 1.2e+03     |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 24          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.001108318 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.0911      |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0132      |
# |    loss                 | 1.15e+04    |
# |    n_updates            | 9050        |
# |    policy_gradient_loss | -0.000356   |
# |    value_loss           | 2.3e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 1.26e+03    |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 25          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.001418221 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.0886      |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0127      |
# |    loss                 | 1.34e+04    |
# |    n_updates            | 9060        |
# |    policy_gradient_loss | -0.000549   |
# |    value_loss           | 2.69e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 1.29e+03     |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 26           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0004793076 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.086        |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0122       |
# |    loss                 | 1.44e+04     |
# |    n_updates            | 9070         |
# |    policy_gradient_loss | -0.000262    |
# |    value_loss           | 2.87e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 1.34e+03     |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 27           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0012532417 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.0834       |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0117       |
# |    loss                 | 1.17e+04     |
# |    n_updates            | 9080         |
# |    policy_gradient_loss | -0.000375    |
# |    value_loss           | 2.35e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 1.33e+03     |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 28           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0013888968 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.0809       |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0112       |
# |    loss                 | 1.19e+04     |
# |    n_updates            | 9090         |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 2.39e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 1.34e+03    |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 29          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.002409232 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.0783      |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0107      |
# |    loss                 | 1.43e+04    |
# |    n_updates            | 9100        |
# |    policy_gradient_loss | 0.000298    |
# |    value_loss           | 2.86e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 1.34e+03     |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 30           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0014230099 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.0758       |
# |    entropy_loss         | -0.888       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0102       |
# |    loss                 | 1.22e+04     |
# |    n_updates            | 9110         |
# |    policy_gradient_loss | -0.000481    |
# |    value_loss           | 2.43e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 1.32e+03     |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 31           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0009111544 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.0732       |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00966      |
# |    loss                 | 1.09e+04     |
# |    n_updates            | 9120         |
# |    policy_gradient_loss | -6.53e-05    |
# |    value_loss           | 2.18e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | 1.28e+03     |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 32           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0005868877 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.0706       |
# |    entropy_loss         | -0.905       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00914      |
# |    loss                 | 1.15e+04     |
# |    n_updates            | 9130         |
# |    policy_gradient_loss | -5.82e-05    |
# |    value_loss           | 2.3e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 151           |
# |    ep_rew_mean          | 1.34e+03      |
# | time/                   |               |
# |    fps                  | 316           |
# |    iterations           | 33            |
# |    time_elapsed         | 213           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00036792172 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0681        |
# |    entropy_loss         | -0.902        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00863       |
# |    loss                 | 1.23e+04      |
# |    n_updates            | 9140          |
# |    policy_gradient_loss | -0.000342     |
# |    value_loss           | 2.45e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 156           |
# |    ep_rew_mean          | 1.43e+03      |
# | time/                   |               |
# |    fps                  | 316           |
# |    iterations           | 34            |
# |    time_elapsed         | 219           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00029944177 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0655        |
# |    entropy_loss         | -0.893        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00812       |
# |    loss                 | 1.33e+04      |
# |    n_updates            | 9150          |
# |    policy_gradient_loss | -0.000221     |
# |    value_loss           | 2.65e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 153           |
# |    ep_rew_mean          | 1.37e+03      |
# | time/                   |               |
# |    fps                  | 315           |
# |    iterations           | 35            |
# |    time_elapsed         | 226           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 6.2659004e-05 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.063         |
# |    entropy_loss         | -0.895        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00761       |
# |    loss                 | 1.32e+04      |
# |    n_updates            | 9160          |
# |    policy_gradient_loss | 5.99e-07      |
# |    value_loss           | 2.65e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 157           |
# |    ep_rew_mean          | 1.45e+03      |
# | time/                   |               |
# |    fps                  | 315           |
# |    iterations           | 36            |
# |    time_elapsed         | 233           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00029804217 |
# |    clip_fraction        | 0.0725        |
# |    clip_range           | 0.0604        |
# |    entropy_loss         | -0.887        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0071        |
# |    loss                 | 1.16e+04      |
# |    n_updates            | 9170          |
# |    policy_gradient_loss | -0.00057      |
# |    value_loss           | 2.32e+04      |
# -------------------------------------------

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
env.close()
mean_reward, std_reward
